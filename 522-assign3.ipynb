# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All). Make sure your notebook executed to the end.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE." Please remember that homeworks are to be completed independently. You may not share code with others.

# %%
NAME = "Allison Yih"

# %% [markdown]
# ---

# %% [markdown]
# # Information Visualization I
# ## School of Information, University of Michigan
#
# ## Week 3:
# - Perception / Cognition
#
# ## Assignment Overview
# ### This assignment's objectives include:
#
# - Review, refect, and apply the concepts of the perception pipeline. Justify how different encodings impact the effectiveness of a visualization depending on the human perception process.
#
# !["Drowing"](assets/preattentive_resized.png)
#
# <p style="text-align: center;"> Preattentive Processing </p>
#
# - Recreate visualizations and propose new and alternative visualizations using [Altair](https://altair-viz.github.io/)
#
# ### The total score of this assignment will be 100 points consisting of:
# - Case study reflection: America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters) (30 points)
# - Altair programming exercise (70 points)
#
# ### Resources:
# - Article by [FiveThirtyEight](https://fivethirtyeight.com) available  [online](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) (Hickey, 2014)
# - Datasets from FiveThirtyEight, we have downloaded a subset of this data in the folder [./assets](assets)
#     - The original dataset can be found at [FiveThirtyEight Star Wars Survey](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
#
# ### Important notes:
# 1) Grading for this assignment is entirely done by manual inspection. Focus on getting the visualization to look like our example. It doesn't need to be pixel perfect (e.g., you may not always know what our example is scaled by), but it should be pretty close. Hint: go back to lab in week 2 on altair for some styling help. A *lot* of the look and feel can be done in one line of code.
#
# 2) There will be a couple of places where the numbers you get when you select rows may be a little different than 538, but the percents should still work (e.g., 828 instead of 834). You'll see this in our examples. If you can somehow get the data to match exactly, that's great too.
#
# 3) When turning in your PDF, please use the File -> Print -> Save as PDF option ***from your browser***. Do ***not*** use the File->Download as->PDF option. Complete instructions for this are under Resources in the Coursera page for this class.

# %% [markdown]
# ## Part 1. Perception and Cognition (30 points)
# Read the article ["America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters),"](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/) and answer the following questions:

# %% [markdown]
# ### 1.1 List the different data types in the following visualizations and their encodings (10 points)
# Look at the following visualizations. For each, list the variable, their type, and the encoding used (e.g., Weight, quantitative, color, ...)
#
# !["Drowing"](assets/how_rate_resized.png)
# !["Drowing"](assets/have_seen_resized.png)

# %% [markdown]
# In the top visualization, it encodes the movie title, which is a qualitative variable, as text. The percent of respondents who rated the film as top third is a quantitative variable that is found in the visualization; it is encoded in green colour. The percent of respondents who rated the film as middle third is another quantitative variable that is found in the visualization; it is encoded in blue colour. The percent of respondents who rated the film as bottom third is another quantitative variable that is found in the visualization; it is encoded in red colour.
#
# In the bottom visualization, it encodes the movie title, which is a qualitative, nominal variable, as text. The percent of respondents who have seen the film is a quantitative variable that is also found in the visualization, and it is encoded in blue colour and the bar size.

# %% [markdown]
# ### 1.2 Propose an alternative encoding for the following visualization. Compare the visualizations based on perception. (10 points)
# Either hand-draw or use an application to create a sketched solution. Upload an image and describe the differences between your solution and the FiveThirtyEight image in terms of perception (specifically for the task of comparing one movie to another).
# !["Drowing"](assets/have_seen_resized.png)

# %% [markdown]
# !['answer1.2'](assets/1.2.jpeg)

# %% [markdown]
# ### 1.3 Propose an alternative encoding for the following visualization. Compare the visualizations based on perception. (10 points)
# Again, either-hand draw or use an application to create a sketched solution. Upload an image and describe the differences between your solution and the FiveThirtyEight image in terms of perception (specifically for the task of comparing one movie to another).
# !["Drowing"](assets/how_rate_resized.png)

# %% [markdown]
# !['answer1.3'](assets/1.3.jpeg)

# %% [markdown]
# ## Part 2. Altair programming exercise (70 points)
# We have provided you with some code and parts of the article [America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/). This article is based on the dataset:
#
# 1. [StarWars](data/StarWars.csv) Created by FiveThirtyEight based on a survey ran through SurveyMonkey Audience, surveying 1,186 respondents from June 3 to 6 2014. Available [online] (https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)
#
# To earn points for this assignment, you must:
#
# - Recreate the visualizations in the article (replace the images in the article with a code cell that creates a visualization). We provide one example. Each visualization is worth 10 points (40 points/ 10 each x 4 total ).
#
#     - _Partial credit can be granted for each visualization (up to 5 points) if you provide the grammar of graphics description of the visualization without a functional Altair implementation_
#
#
# - Propose one alternative visualization for one of the article visualizations. Add a short paragraph describing why your visualization is more *effective* based on principles of perception/cognition. (15 points/ 10 points plot + 5 justification)
#
#
# - Propose a new visualization to complement a part of the article. Add a short paragraph justifying your decisions in terms of Perception/Cognition processes.  (15 points/ 10 points plot + 5 justification)

# %%
import pandas as pd
import altair as alt
import numpy as np
import math

# %%
# enable correct rendering
alt.renderers.enable('default')
# Out:
# RendererRegistry.enable('default')

# %%
# uses intermediate json files to speed things up
alt.data_transformers.enable('json')
# Out:
# DataTransformerRegistry.enable('json')

# %%
sw = pd.read_csv('assets/StarWars.csv', encoding='latin1')

# %%
# Some format is needed for the survey dataframe, we provide the formatted dataset in a dataframe 
sw = sw.rename(columns={'Have you seen any of the 6 films in the Star Wars franchise?':'seen_any_movie',
                        'Do you consider yourself to be a fan of the Star Wars film franchise?': 'fan',
                        'Which of the following Star Wars films have you seen? Please select all that apply.' : 'seen_EI',
                        'Unnamed: 4' : 'seen_EII',
                        'Unnamed: 5' : 'seen_EIII',
                        'Unnamed: 6' : 'seen_EIV',
                        'Unnamed: 7' : 'seen_EV',
                        'Unnamed: 8' : 'seen_EVI',
                        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.' : 'rank_EI',
                        'Unnamed: 10' : 'rank_EII',
                        'Unnamed: 11' : 'rank_EIII',
                        'Unnamed: 12' : 'rank_EIV',
                        'Unnamed: 13' : 'rank_EV',
                        'Unnamed: 14' : 'rank_EVI',
                        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.' : 'Han Solo',
                        'Unnamed: 16' : 'Luke Skywalker',
                        'Unnamed: 17' : 'Princess Leia Organa',
                        'Unnamed: 18' : 'Anakin Skywalker',
                        'Unnamed: 19' : 'Obi Wan Kenobi',
                        'Unnamed: 20' : 'Emperor Palpatine',
                        'Unnamed: 21' : 'Darth Vader',
                        'Unnamed: 22' : 'Lando Calrissian',
                        'Unnamed: 23' : 'Boba Fett',
                        'Unnamed: 24' : 'C-3P0',
                        'Unnamed: 25' : 'R2 D2',
                        'Unnamed: 26' : 'Jar Jar Binks',
                        'Unnamed: 27' : 'Padme Amidala',
                        'Unnamed: 28' : 'Yoda',
                       })
sw = sw.drop([0])

# %%
# take a peak to look at the data
sw.sample(5)
# Out:
#      RespondentID seen_any_movie  fan  \
# 447  3.290555e+09             No  NaN
# 348  3.290734e+09            Yes   No
# 548  3.290287e+09             No  NaN
# 972  3.288719e+09            Yes   No
# 477  3.290472e+09            Yes  Yes
#
#                                       seen_EI  \
# 447                                       NaN
# 348  Star Wars: Episode I  The Phantom Menace
# 548                                       NaN
# 972  Star Wars: Episode I  The Phantom Menace
# 477  Star Wars: Episode I  The Phantom Menace
#
#                                         seen_EII  \
# 447                                          NaN
# 348                                          NaN
# 548                                          NaN
# 972  Star Wars: Episode II  Attack of the Clones
# 477  Star Wars: Episode II  Attack of the Clones
#
#                                        seen_EIII  \
# 447                                          NaN
# 348                                          NaN
# 548                                          NaN
# 972                                          NaN
# 477  Star Wars: Episode III  Revenge of the Sith
#
#                               seen_EIV  \
# 447                                NaN
# 348                                NaN
# 548                                NaN
# 972  Star Wars: Episode IV  A New Hope
# 477  Star Wars: Episode IV  A New Hope
#
#                                           seen_EV  \
# 447                                           NaN
# 348                                           NaN
# 548                                           NaN
# 972  Star Wars: Episode V The Empire Strikes Back
# 477  Star Wars: Episode V The Empire Strikes Back
#
#                                      seen_EVI rank_EI  ...  \
# 447                                       NaN     NaN  ...
# 348                                       NaN       1  ...
# 548                                       NaN     NaN  ...
# 972  Star Wars: Episode VI Return of the Jedi       3  ...
# 477  Star Wars: Episode VI Return of the Jedi       6  ...
#
#                    Yoda       Which character shot first?  \
# 447                 NaN                               NaN
# 348  Somewhat favorably  I don't understand this question
# 548                 NaN                               NaN
# 972      Very favorably  I don't understand this question
# 477      Very favorably                               Han
#
#     Are you familiar with the Expanded Universe?  \
# 447                                          NaN
# 348                                           No
# 548                                          NaN
# 972                                           No
# 477                                          Yes
#
#     Do you consider yourself to be a fan of the Expanded Universe?æ  \
# 447                                                NaN
# 348                                                NaN
# 548                                                NaN
# 972                                                NaN
# 477                                                Yes
#
#     Do you consider yourself to be a fan of the Star Trek franchise?  Gender  \
# 447                                                 No                  Male
# 348                                                 No                  Male
# 548                                                 No                Female
# 972                                                Yes                Female
# 477                                                Yes                  Male
#
#        Age   Household Income           Education Location (Census Region)
# 447  18-29          $150,000+     Bachelor degree       West South Central
# 348  45-60  $25,000 - $49,999     Bachelor degree                  Pacific
# 548   > 60  $50,000 - $99,999  High school degree           South Atlantic
# 972  18-29  $25,000 - $49,999     Bachelor degree       West South Central
# 477  45-60       $0 - $24,999     Bachelor degree              New England
#
# [5 rows x 38 columns]

# %% [markdown]
# # America’s Favorite ‘Star Wars’ Movies (And Least Favorite Characters)

# %% [markdown]
# _Original article available at [FiveThirtyEight](https://fivethirtyeight.com/features/americas-favorite-star-wars-movies-and-least-favorite-characters/)_
#
# By [Walt Hickey](https://fivethirtyeight.com/contributors/walt-hickey/)
#
# Filed under [Movies](https://fivethirtyeight.com/tag/movies/)
#
# Get the data on [GitHub](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey)

# %% [markdown]
# This week, I caught a sneak peek [of the X-Wing fighter](http://www.wired.com/2014/07/star-wars-episode-vii-x-wing/) from the new “Star Wars” films in production. The forthcoming movies — and the middling response to the most recent trilogy — provide a perfect excuse to examine some questions I’ve long wanted answers to: How many people are “Star Wars” fans? Does the rest of America realize that “The Empire Strikes Back” is clearly the best of the bunch? Which characters are most well-liked and most hated? And who shot first, Han Solo or Greedo?
#
# We ran a poll through [SurveyMonkey Audience](https://www.surveymonkey.com/mp/audience/), surveying 1,186 respondents from June 3 to 6 (the [data](https://github.com/fivethirtyeight/data/tree/master/star-wars-survey) is available [on GitHub](https://github.com/fivethirtyeight/data)). Seventy-nine percent of those respondents said they had watched at least one of the “Star Wars” films. This question, incidentally, had a substantial difference by gender: 85 percent of men have seen at least one “Star Wars” film compared to 72 percent of women. Of people who have seen a film, men were also more likely to consider themselves a fan of the franchise: 72 percent of men compared to 60 percent of women.
#
# We then asked respondents which of the films they had seen. With 835 people responding, here’s the probability that someone has seen a given “Star Wars” film given that they have seen any Star Wars film:

# %% [markdown]
# !["Sol1"](assets/have_seen_resized.png)

# %%
# Sample visualization

# We're going to fix the labels a bit so will create a mapping to the full names
episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
names = {
    'EI' : 'The Phantom Menance', 'EII' : 'Attack of the clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
}

# we're also going to use this order to sort, so names_l will now have our sort order
names_l = [names[ep] for ep in episodes]

print("sort order: ",names_l)
# Out:
# sort order:  ['The Phantom Menance', 'Attack of the clones', 'Revenge of the Sith', 'A New Hope', 'The Empire Strikes Back', 'The Return of the Jedi']

# %%
# let's do some data pre-processing... sw (star wars) has everything

# We want to only use those people who have seen at least one movie, let's get the people, toss NAs
# and get the total count

# find people who have at least on of the columns (seen_*) not NaN
seen_at_least_one = sw.dropna(subset=['seen_' + ep for ep in episodes],how='all')
total = len(seen_at_least_one)

print("total who have seen at least one: ", total)
# Out:
# total who have seen at least one:  835

# %%
# for each movie, we're going to calculate the percents and generate a new data frame
percs = []

# loop over each column and calculate the number of people who have seen the movie
# specifically, filter out the people who are *NaN* for a specific episode (e.g., ep_EII), count them
# and divide by the percent
for seen_ep in ['seen_' + ep for ep in episodes]:
    perc = len(seen_at_least_one[~ pd.isna(seen_at_least_one[seen_ep])]) / total
    percs.append(perc)
    
# at this point percs is holding our percentages

# now we're going use a trick to make tuples--pairing names with percents--using "zip" and then make a dataframe
tuples = list(zip([names[ep] for ep in episodes],percs))
seen_per_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])
seen_per_df
# Out:
#                       Name  Percentage
# 0      The Phantom Menance    0.805988
# 1     Attack of the clones    0.683832
# 2      Revenge of the Sith    0.658683
# 3               A New Hope    0.726946
# 4  The Empire Strikes Back    0.907784
# 5   The Return of the Jedi    0.883832

# %%
# ok, time to make the chart... let's make a bar chart (use mark_bar)
bars = alt.Chart(seen_per_df).mark_bar(size=20).encode(
    # encode x as the percent, and hide the axis
    x=alt.X(
        'Percentage',
        axis=None),
    y=alt.Y(
        # encode y using the name, use the movie name to label the axis, sort using the names_l
        'Name:N',
         axis=alt.Axis(tickCount=5, title=''),
         # we give the sorting order to avoid alphabetical order
         sort=names_l
    )
)

# at this point we don't really have a great plot (it's missing the annotations, titles, etc.)
bars
# Out:
# alt.Chart(...)

# %%
# we're going to overlay the text with the percentages, so let's make another visualization
# that's just text labels

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    # we'll use the percentage as the text
    text=alt.Text('Percentage:Q',format='.0%')
)

# finally, we're going to combine the bars and the text and do some styling
seen_movies = (text + bars).configure_mark(
    # we don't love the blue
    color='#008fd5'
).configure_view(
    # we don't want a stroke around the bars
    strokeWidth=0
).configure_scale(
    # add some padding
    bandPaddingInner=0.2
).properties(
    # set the dimensions of the visualization
    width=500,
    height=180
).properties(
    # add a title
    title="Which 'Star Wars' Movies Have you Seen?"
)

seen_movies

# note that we are NOT formatting this in the Five Thirty Eight Style yet... we'll leave that to you to figure out
# Out:
# alt.LayerChart(...)

# %% [markdown]
# So we can see that “Star Wars: Episode V — The Empire Strikes Back” is the film seen by the most number of people, followed by “Star Wars: Episode VI — Return of the Jedi.” Appallingly, more people reported seeing “Star Wars: Episode I — The Phantom Menace” than the original “Star Wars” (renamed “Star Wars: Episode IV — A New Hope”).
#
# So, which movie is the best? We asked the subset of 471 respondents who indicated they have seen every “Star Wars” film to rank them from best to worst. From that question, we calculated the share of respondents who rated each film as their favorite.

# %% [markdown]
# !["Sol1"](assets/best_movie_article_resized.png)
#
#
# ** Homework note: Click [here](assets/best_movie.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.1 What's the best 'Star Wars' movie? Recreate the above image using altair (10 POINTS)

# %%
# Recreate this image using Altair
# try to match the "538 style" as best you can (hint: look at the altair lab at the start of the semester)
episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
names = {
    'EI' : 'The Phantom Menance', 'EII' : 'Attack of the clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
}

names_l = [names[ep] for ep in episodes]

seen_all = sw.dropna(subset=['seen_' + ep for ep in episodes],how='any')
res = []
for rank in ['rank_' + ep for ep in episodes]:
    total = (seen_all[rank] == '1').sum()
    res.append(total)
    
perc2 = []
for total in res:
    pct = total/len(seen_all)
    perc2.append(pct)

tuples = list(zip([names[ep] for ep in episodes],perc2))
best_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(best_df).mark_bar(size=20).encode(
    # encode x as the percent, and hide the axis
    x=alt.X(
        'Percentage',
        axis=None),
    y=alt.Y(
        'Name:N',
         axis=alt.Axis(tickCount=5, title=''),
         sort=names_l
    )
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    # we'll use the percentage as the text
    text=alt.Text('Percentage:Q',format='.0%')
)

seen_movies = (text + bars).configure_mark(
    # we don't love the blue
    color='#008fd5'
).configure_view(
    # we don't want a stroke around the bars
    strokeWidth=0
).properties(
    # set the dimensions of the visualization
    width=500,
    height=180
).properties(
    # add a title
    title="What's the Best Star Wars Movie?"
)

seen_movies

# YOUR CODE HERE
#raise NotImplementedError()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Make sure to *style* your visualization to match the original the best you can

# %% [markdown]
# We can also drill down and find out, generally, how people rate the films. Overall, fans broke into two camps: those who preferred the original three movies and those who preferred the three prequels. People who said “The Empire Strikes Back” was their favorite were also likely to rate “A New Hope” and “Return of the Jedi” higher as well. Those who rated “The Phantom Menace” as the best film were more likely to rate prequels higher.
#
# This chart shows how often each film was rated in the top third (best or second-best), the middle third (third or fourth) or the bottom third (second-worst or worst). It’s a more nuanced take on the series:

# %% [markdown]
# !["Sol1"](assets/how_rate_resized.png)
#
# ** Homework note: Click [here](assets/people_rate.png) to see a version of this plot generated in Altair.

# %% [markdown]
# ### 2.2 How people rate the 'Star Wars' movie? Recreate the above image using altair (10 POINTS)

# %%
# Recreate this image using altair here (10 POINTS)

# YOUR CODE HERE
3#raise NotImplementedError()
episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
names = {
    'EI' : 'The Phantom Menance', 'EII' : 'Attack of the clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
}

names_l = [names[ep] for ep in episodes]

seen_all = sw.dropna(subset=['seen_' + ep for ep in episodes],how='any')

res = []
for rank in ['rank_' + ep for ep in episodes]:
    t1 = (seen_all[rank] == '1').sum()
    t2 = (seen_all[rank] == '2').sum()
    total = t1+t2
    res.append(total)
    
perc2 = []
for total in res:
    pct = total/len(seen_all)
    perc2.append(pct)

tuples = list(zip([names[ep] for ep in episodes],perc2))
best_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(best_df).mark_bar(size=20, color = '#8fd500', strokeWidth = 0).encode(
    # encode x as the percent, and hide the axis
    x=alt.X(
        'Percentage',
        axis=None),
    y=alt.Y(
        'Name:N',
         axis=alt.Axis(tickCount=5, title=''),
         sort=names_l
    )
)

text = bars.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    # we'll use the percentage as the text
    text=alt.Text('Percentage:Q',format='.0%')
)

top_third = (text + bars).properties(
    # set the dimensions of the visualization
    width=75,
    height=300
).properties(
    # add a title
    title="Top third"
)
top_third
# Out:
# alt.LayerChart(...)

# %%
res2 = []
for rank in ['rank_' + ep for ep in episodes]:
    t1 = (seen_all[rank] == '3').sum()
    t2 = (seen_all[rank] == '4').sum()
    total = t1+t2
    res2.append(total)
    
perc3 = []
for total in res2:
    pct = total/len(seen_all)
    perc3.append(pct)

tuples = list(zip([names[ep] for ep in episodes],perc3))
middle_third_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars2 = alt.Chart(middle_third_df).mark_bar(size=20, color = '#008fd5', strokeWidth = 0).encode(
    # encode x as the percent, and hide the axis
    x=alt.X(
        'Percentage',
        axis=None),
    y=alt.Y(
        'Name:N',
         axis=alt.Axis(tickCount=5, title=''),
         sort=names_l
    )
)

text2 = bars2.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    # we'll use the percentage as the text
    text=alt.Text('Percentage:Q',format='.0%')
)

middle_third = (text2 + bars2).properties(
    # set the dimensions of the visualization
    width=75,
    height=300
).properties(
    # add a title
    title="Middle third"
)
middle_third
# Out:
# alt.LayerChart(...)

# %%
res3 = []
for rank in ['rank_' + ep for ep in episodes]:
    t1 = (seen_all[rank] == '5').sum()
    t2 = (seen_all[rank] == '6').sum()
    total = t1+t2
    res3.append(total)
    
perc4 = []
for total in res3:
    pct = total/len(seen_all)
    perc4.append(pct)
    
tuples = list(zip([names[ep] for ep in episodes],perc4))
bottom_third_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars3 = alt.Chart(bottom_third_df).mark_bar(size=20, color = '#ff0000', strokeWidth = 0).encode(
    # encode x as the percent, and hide the axis
    x=alt.X(
        'Percentage',
        axis=None),
    y=alt.Y(
        'Name:N',
         axis=alt.Axis(tickCount=5, title=''),
         sort=names_l
    )
)

text3 = bars3.mark_text(
    align='left',
    baseline='middle',
    dx=3  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    # we'll use the percentage as the text
    text=alt.Text('Percentage:Q',format='.0%')
)

bottom_third = (text3 + bars3).properties(
    # set the dimensions of the visualization
    width=75,
    height=300
).properties(
    # add a title
    title="Bottom third"
)
bottom_third
# Out:
# alt.LayerChart(...)

# %%
res_chart = alt.hconcat(top_third, middle_third, bottom_third).properties(title = {"text": ["How People Rate the Star Wars' Movies"], "subtitle": ["How often each film was rated in the top, middle, and bottom third", "by 471 respondents who have seen all six films"], "subtitleColor":"grey"}).configure_scale(bandPaddingInner = 0.2).configure_view(strokeWidth = 0).configure(background = '#dcdcdc')
res_chart
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# Finally, we took a boilerplate format used by political favorability polls — “Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her” — and asked respondents to rate characters in the series.

# %% [markdown]
# !["Sol1"](assets/char_ranking_resized.png)
#
#
# ** Homework note. Here's an example solution generated in Altair:
# !["Sol1"](assets/people_rate_s.png)

# %% [markdown]
# ### 2.3 Star Wars' Characters Favorability Ratings. Recreate the above image using altair (10 POINTS)

# %%
# Recreate this image using altair here (10 POINTS)
characters = ['Luke Skywalker', 'Han Solo', 'Princess Leia Organa', 'Obi Wan Kenobi','Yoda','R2 D2', 'C-3P0', 'Anakin Skywalker', 'Darth Vader', 'Lando Calrissian', 'Padme Amidala', 'Boba Fett', 'Emperor Palpatine', 'Jar Jar Binks']

seen_at_least_one = sw.dropna(subset = ['Luke Skywalker', 'Han Solo', 'Princess Leia Organa', 'Obi Wan Kenobi','Yoda','R2 D2', 'C-3P0', 'Anakin Skywalker', 'Darth Vader', 'Lando Calrissian', 'Padme Amidala', 'Boba Fett', 'Emperor Palpatine', 'Jar Jar Binks'], how = 'all')

res = []
for name in characters:
    total = (seen_at_least_one[name] == 'Very favorably').sum() + (seen_at_least_one[name] == 'Somewhat favorably').sum()
    res.append(total)
    
pct = []
for total in res:
    pct.append(total/seen_at_least_one[name].count())
    
tuples = list(zip([name for name in characters],pct))
best_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(best_df).mark_bar(size = 20, strokeWidth = 0, color = '#228B22').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = characters, axis = alt.Axis(tickCount = 5, title = ''))
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
favorable_plot = (bars + text).properties(title = {"text": ["Favorable"]}).properties(width = 75, height = 300)

res2 = []
for name in characters:
    total = (seen_at_least_one[name] == 'Neither favorably nor unfavorably (neutral)').sum() 
    res2.append(total)
    
pct2 = []
for total in res2:
    pct2.append(total/seen_at_least_one[name].count())

tuples = list(zip([name for name in characters],pct2))
neutral_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(neutral_df).mark_bar(size = 20, strokeWidth = 0, color = '#008fd5').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = characters, axis = alt.Axis(tickCount = 5, title = ''))
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
neutral_plot = (bars + text).properties(title = {"text": ["Neutral"]}).properties(width = 75, height = 300)

res3 = []
for name in characters:
    total = (seen_at_least_one[name] == 'Somewhat unfavorably').sum() + (seen_at_least_one[name] == 'Very unfavorably').sum() 
    res3.append(total)
    
pct3 = []
for total in res3:
    pct3.append(total/seen_at_least_one[name].count())

tuples = list(zip([name for name in characters],pct3))
unfavorable_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(unfavorable_df).mark_bar(size = 20, strokeWidth = 0, color = 'red').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = characters, axis = alt.Axis(tickCount = 5, title = ''))
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
unfavorable_plot = (bars + text).properties(title = {"text": ["Unfavorable"]}).properties(width = 75, height = 300)

res4 = []
for name in characters:
    total = (seen_at_least_one[name] == 'Unfamiliar (N/A)').sum() 
    res4.append(total)
    
pct4 = []
for total in res4:
    pct4.append(total/seen_at_least_one[name].count())

tuples = list(zip([name for name in characters],pct4))
unfamiliar_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(unfamiliar_df).mark_bar(size = 20, strokeWidth = 0, color = 'gray').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = characters, axis = alt.Axis(tickCount = 5, title = ''))
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
unfamiliar_plot = (bars + text).properties(title = {"text": ["Unfamiliar"]}).properties(width = 75, height = 300)

res_chart = alt.hconcat(favorable_plot, neutral_plot, unfavorable_plot, unfamiliar_plot).properties(title = {"text": ["Star Wars Character Favoribility Rankings"], "subtitle": ["By 834 respondents"]}).configure_view(strokeWidth = 0).configure_scale(bandPaddingInner = 0.2).configure(background = '#dcdcdc')
res_chart
# YOUR CODE HERE
#raise NotImplementedError()
# Out:
# alt.HConcatChart(...)

# %% [markdown]
# You read that correctly. Jar Jar Binks has a lower favorability rating than the actual personification of evil in the galaxy.
#
# And for those of you who want to know the impact that [historical revisionism](http://en.wikipedia.org/wiki/Han_shot_first) can have on a society:
#
# !["Sol1"](assets/shot_first_article_resized.png)
#
#
# ** Homework note: Click [here](assets/shot_first.png) to see a version of this plot generated in Altair. You may find that you don't get 834 rows (as 538 did) but the percents should still work.

# %% [markdown]
# ### 2.4 Who shot first? Recreate the above image using altair (10 POINTS)

# %%
# Recreate this image using altair here (10 POINTS)

sw_copy = sw
sw_copy['Pre-Han'] = np.where(sw_copy['Which character shot first?'].isin(['Han']), 1,0)
sw_copy['Han'] = sw_copy['Pre-Han'].replace(1, 'Han')
sw_copy['Han'] = sw_copy['Han'].replace(0, np.NaN)

sw_copy['Pre-Greedo'] = np.where(sw_copy['Which character shot first?'].isin(['Greedo']), 1,0)
sw_copy['Greedo'] = sw_copy['Pre-Greedo'].replace(1, 'Greedo')
sw_copy['Greedo'] = sw_copy['Greedo'].replace(0, np.NaN)

sw_copy['Pre-Dont-Understand'] = np.where(sw_copy['Which character shot first?'].isin(["I don't understand this question"]), 1,0)
sw_copy["I don't understand this question"] = sw_copy['Pre-Dont-Understand'].replace(1, "I don't understand this question")
sw_copy["I don't understand this question"] = sw_copy["I don't understand this question"].replace(0, np.NaN)

names_l = ['Han', 'Greedo', "I don't understand this question"]

shot_first = sw_copy.dropna(subset = ['Han', 'Greedo', "I don't understand this question"], how = 'all')
res = [shot_first['Han'].count(), shot_first['Greedo'].count(), shot_first["I don't understand this question"].count() ]
    
pct = []
for total in res:
    pct.append(total/len(shot_first))
    
tuples = list(zip([name for name in names_l],pct))
shot_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(shot_df).mark_bar(size = 20, strokeWidth = 0, color = '#008fd5').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = names_l, axis = alt.Axis(tickCount = 5, title = ''))
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
shot_plot = (bars + text).properties(title = {"text": ["Who Shot First?"],"subtitle": ["According to 834 respondents"], "subtitleColor": "gray" }).properties(width = 75, height = 300).configure_view(strokeWidth = 0).configure_scale(bandPaddingInner = 0.2).properties(width = 500, height = 200).configure(background = '#dcdcdc')
shot_plot
# YOUR CODE HERE
#raise NotImplementedError()
# Out:
# alt.LayerChart(...)

# %%
#print(total)

# %% [markdown]
# ### 2.5.1 Make your own (15 points/ 10 points plot + 5 justification)
#
# Propose and code an alternative visualization for one of the visualizations *already in the article*. Add a short paragraph describing why your visualization is more (or less) *effective* based on principles of perception/cognition.
#
# If you feel your visualization is worse, that's ok! Just tell us why.

# %%
sw_copy = sw
sw_copy['Pre-Han'] = np.where(sw_copy['Which character shot first?'].isin(['Han']), 1,0)
sw_copy['Han'] = sw_copy['Pre-Han'].replace(1, 'Han')
sw_copy['Han'] = sw_copy['Han'].replace(0, np.NaN)

sw_copy['Pre-Greedo'] = np.where(sw_copy['Which character shot first?'].isin(['Greedo']), 1,0)
sw_copy['Greedo'] = sw_copy['Pre-Greedo'].replace(1, 'Greedo')
sw_copy['Greedo'] = sw_copy['Greedo'].replace(0, np.NaN)

sw_copy['Pre-Dont-Understand'] = np.where(sw_copy['Which character shot first?'].isin(["I don't understand this question"]), 1,0)
sw_copy["I don't understand this question"] = sw_copy['Pre-Dont-Understand'].replace(1, "I don't understand this question")
sw_copy["I don't understand this question"] = sw_copy["I don't understand this question"].replace(0, np.NaN)

names_l = ['Han', 'Greedo', "I don't understand this question"]

shot_first = sw_copy.dropna(subset = ['Han', 'Greedo', "I don't understand this question"], how = 'all')
res = [shot_first['Han'].count(), shot_first['Greedo'].count(), shot_first["I don't understand this question"].count() ]
    
pct = []
for total in res:
    pct.append(total/len(shot_first))
    
tuples = list(zip([name for name in names_l],pct))
shot_df2 = pd.DataFrame(tuples, columns = ['Answer', 'Percentage of Answer'])


bars = alt.Chart(shot_df2).mark_bar(size = 10).encode(
    x=alt.X('Answer', axis = None),
    y = alt.Y('Percentage of Answer:Q', sort = names_l),
    color=alt.Color('Answer')
)
text = bars.encode(text = alt.Text('Percentage of Answer:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
question_plot = (bars + text).properties(title = {"text": ["Who Shot First?"], "subtitle": ["According to 835 Respondents"]}).configure_view(strokeWidth = 0).configure_scale(bandPaddingInner = 0.2).properties(width = 500, height = 200)
question_plot
# YOUR CODE HERE
#raise NotImplementedError()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# I revised the visualization for "Who Shot First" by changing the colour scheme for each answer type to a hue, rather than having all of bars representing the different answers in the same colour. I also reoriented the bar chart to a vertical layout, and added in an axis label to elaborate on what specifically the percent variable was describing.
#
# Based on the perception and cognition principles, my visualization seems to be more effective since having a varying hue for each of the different answer categories would help the viewer better distinguish the percentage of respondents who say a certain answer for the question about who shot first. Additionally, by reorienting the plot, the bar length, which is a preattentive quality, seems to help make it easier and faster to process which answer stands out, which in this case, is the one with the shortest and longest bar lengths.

# %% [markdown]
# ### 2.5.2 Make your own (15 points/ 10 points plot + 5 justification)
# Propose and code a *new visualization* to complement a part of the article. Add a short paragraph justifying your decisions in terms of Perception/Cognition processes.
#
# If you feel your visualization is worse, that's ok! Just tell us why.

# %%
sw_copy = sw 

episodes = ['EI', 'EII', 'EIII', 'EIV', 'EV', 'EVI']
names = {
    'EI' : 'The Phantom Menance', 'EII' : 'Attack of the clones', 'EIII' : 'Revenge of the Sith', 
    'EIV': 'A New Hope', 'EV': 'The Empire Strikes Back', 'EVI' : 'The Return of the Jedi'
}

sw_copy = sw_copy.dropna(subset=['seen_' + ep for ep in episodes],how='all')

#sw_copy['Age'].unique()
ages = ['18-29', '30-44',  '45-60',  '> 60']
sw_copy['Pre-18'] = np.where(sw_copy['Age'].isin(['18-29']), 1,0)
sw_copy['18-29'] = sw_copy['Pre-18'].replace(1, '18-29')
sw_copy['18-29'] = sw_copy['18-29'].replace(0, np.NaN)


sw_copy['Pre-30'] = np.where(sw_copy['Age'].isin(['30-44']), 1,0)
sw_copy['30-44'] = sw_copy['Pre-30'].replace(1, '30-44')
sw_copy['30-44'] = sw_copy['30-44'].replace(0, np.NaN)

sw_copy['Pre-45'] = np.where(sw_copy['Age'].isin(['45-60']), 1,0)
sw_copy['45-60'] = sw_copy['Pre-45'].replace(1, '45-60')
sw_copy['45-60'] = sw_copy['45-60'].replace(0, np.NaN)

sw_copy['Pre-60'] = np.where(sw_copy['Age'].isin(['> 60']), 1,0)
sw_copy['> 60'] = sw_copy['Pre-60'].replace(1, '> 60')
sw_copy['> 60'] = sw_copy['> 60'].replace(0, np.NaN)

names_l = ['18-29', '30-44',  '45-60',  '> 60']

res_age = [sw_copy['18-29'].count(), sw_copy['30-44'].count(), sw_copy['45-60'].count(), sw_copy['> 60'].count() ]
pct_age = []
for total in res_age:
    pct_age.append(total/len(sw_copy))
    
tuples = list(zip([name for name in names_l],pct))
ages_df = pd.DataFrame(tuples, columns = ['Name', 'Percentage'])

bars = alt.Chart(ages_df).mark_bar(size = 20, strokeWidth = 0, color = '#008fd5').encode(  
    x = alt.X('Percentage', axis = None),
    y = alt.Y('Name:N', sort = names_l, axis = alt.Axis(tickCount = 5, title = '')),
    color=alt.Color('Name')
    )
text = bars.encode(text = alt.Text('Percentage:Q', format = '.0%')).mark_text(align = 'left', baseline = 'middle', dx=3)
age_plot = (bars + text).properties(title = {"text": ["Age vs Percent of Seeing All Star Movies Movies"],"subtitle": ["According to 835 respondents"], "subtitleColor": "gray" }).properties(width = 75, height = 300).configure_view(strokeWidth = 0).configure_scale(bandPaddingInner = 0.2).properties(width = 500, height = 200).configure(background = '#dcdcdc')
age_plot

# YOUR CODE HERE
#raise NotImplementedError()
# Out:
# alt.LayerChart(...)

# %% [markdown]
# I added in a horizontal bar chart visualization that gives a breakdown of what percentage of people have seen all of the 'Star Wars' movies, based by age group, where each group is represented by a different bar color. Knowing that Star Wars movies are fairly old films, I was curious to see how much of the younger population has seen all of the films in the series, compared to older-aged people.
#
# Based on the perception and cognition principles, my visualization seems to be more effective than the other charts in the article because what the chart is trying to convey is a very simple answer: what age group has the highest percent of individuals who have seen all of the 'Star Wars' movies. While it could have given a more specific answer, such as also taking other factors like education or geographic region into account, the chart does not overcomplicate the answer to that by adding in other variables to give us the overall breakdown. Additionally, the varied color hue helps viewers to quickly distinguish the percent differences between the age groups.
